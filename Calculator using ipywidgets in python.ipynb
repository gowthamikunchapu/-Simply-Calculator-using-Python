# %%
import ipywidgets as w
from IPython.display import display

h=w.Text(desciption="enter operation")
output=w.FloatText(description="")
l1=w.Button(description="1")
l2=w.Button(description="2")
l3=w.Button(description="3")
lAC=w.Button(description="AC")
l4=w.Button(description="4")
l5=w.Button(description="5")
l6=w.Button(description="6")
lEQ=w.Button(description="=")
l7=w.Button(description="7")
l8=w.Button(description="8")
l9=w.Button(description="9")
lplus=w.Button(description="+")
lstar=w.Button(description="*")
l0=w.Button(description="0")
lmin=w.Button(description="-")
ldiv=w.Button(description="/")
lback=w.Button(description="bsp")
boxv=w.HBox([h,output])
box1=w.HBox([l7,l8,l9,lAC,lback])
box2=w.HBox([l4,l5,l6,lEQ])
box3=w.HBox([l1,l2,l3,lplus])
box4=w.HBox([lStar,l0,lmin,ldiv])
tab=w.VBox(([boxv,box1,box2,box3,box4]))
def f7(self):
    h.value=h.value+"7"
def f8(self):
    h.value=h.value+"8"
def f9(self):
    h.value=h.value+"9"
def f6(self):
    h.value=h.value+"6"
def f5(self):
    h.value=h.value+"5"
def f4(self):
    h.value=h.value+"4"
def f3(self):
    h.value=h.value+"3"
def f2(self):
    h.value=h.value+"2"
def f1(self):
    h.value=h.value+"1"
def fplus(self):
    h.value=h.value+"+"
def fmin(self):
    h.value=h.value+"-"
def fstar(self):
    h.value=h.value+"*"
def fdiv(self):
    h.value=h.value+"/"
def f0(self):
    h.value=h.value+"0"
def fEQ(self):
    s=eval(h.value)
    output.value=str(s)
def fclear(self):
    h.value=""
    output.value=0
def fbsp(self):
    h.value=h.value[0:-1]
l1.on_click(f1)
l2.on_click(f2)
l3.on_click(f3)
l4.on_click(f4)
l5.on_click(f5)
l6.on_click(f6)
l7.on_click(f7)
l8.on_click(f8)
l9.on_click(f9)
lplus.on_click(fplus)
lmin.on_click(fmin)
ldiv.on_click(fdiv)
lEQ.on_click(fEQ)
lstar.on_click(fstar)
l0.on_click(f0)
lAC.on_click(fclear)
lback.on_click(fbsp)
display(tab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      25 box2=w.HBox([l4,l5,l6,lEQ])
#      26 box3=w.HBox([l1,l2,l3,lplus])
# ---> 27 box4=w.HBox([lStar,l0,lmin,ldiv])
#      28 tab=w.VBox(([boxv,box1,box2,box3,box4]))
#      29 def f7(self):
#
# NameError: name 'lStar' is not defined
